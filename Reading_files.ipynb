# %% [markdown]
# # ASSIGNMENT-1

# %%
import pandas as pd

# %% [markdown]
# ## 1-Read all kinds of data that we discussed here

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9CB9-E181
#
#  Directory of C:\dataanalytics\pandas_docs
#
# 07/21/2023  11:36 AM    <DIR>          .
# 07/21/2023  11:36 AM    <DIR>          ..
# 07/21/2023  11:33 AM    <DIR>          .ipynb_checkpoints
# 07/21/2023  11:36 AM             3,270 ASSIGNMENT-1.ipynb
# 07/21/2023  11:29 AM           144,411 CLASS1-INTRODUCTION & FILE HANDLING.ipynb
# 07/21/2023  11:30 AM             8,065 CLASS2-DATA WRITING.ipynb
# 07/21/2023  10:33 AM                72 CLASS3-CREATING A DATAFRAME.ipynb
# 07/20/2023  09:26 AM               111 csv_mindex.csv
# 07/20/2023  09:26 AM                59 demo1.csv
# 07/20/2023  09:26 AM            10,545 demo1.xlsx
# 07/20/2023  09:26 AM                43 demo2.csv
# 07/20/2023  09:26 AM               169 demo3.csv
# 07/20/2023  09:26 AM               170 demo3.txt
# 07/20/2023  09:26 AM               169 demo4.csv
# 07/20/2023  09:26 AM                78 demo5.csv
# ...

# %%
#csv_mindex.csv
file=pd.read_csv("csv_mindex.csv")
file
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
#demo1.csv
file_1=pd.read_csv("demo1.csv")
file_1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
#demo1.xlsx
file_2=pd.read_excel("demo1.xlsx")
file_2
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
#demo2.csv
file_3=pd.read_csv("demo2.csv")
file_3
# Out:
#    1   2   3   4  hello
# 0  5   6   7   8  world
# 1  9  10  11  12   file

# %%
#demo3.txt
file_4=pd.read_csv("demo3.txt")
file_4
# Out:
#                A         B         C
# 0  aaa -0.264438 -1.026059 -0.619500
# 1  bbb  0.927272  0.302904 -0.032399
# 2  ccc -0.264273 -0.386314 -0.217601
# 3  ddd -0.871858 -0.348382  1.100491

# %%
#demo4.csv
file_5=pd.read_csv("demo4.csv")
file_5
# Out:
#                                                                  # hey!
# a                                                  b   c   d    message
# # just wanted to make things more understandable   NaN NaN NaN      NaN
# # do you have enough skills to become a data sc... NaN NaN NaN      NaN
# 1                                                  2   3   4      hello
# 5                                                  6   7   8      world
# 9                                                  10  11  12       foo

# %%
#demo5.csv
file_6=pd.read_csv("demo5.csv")
file_6
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
#demo6.csv
file_7=pd.read_csv("demo6.csv")
file_7
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
#demo7.csv
file_8=pd.read_csv("demo7.csv")
file_8
# Out:
#    a  b  c
# 0  1  2  3
# 1  1  2  3

# %%
#demo_file.xlsx
file_9=pd.read_excel("demo_file.xlsx")
file_9
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#fdic_failed_bank_list.html
file=pd.read_html("fdic_failed_bank_list.html")
file_10=file[0]
file_10
# Out:
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# ...

# %%
#final.csv
file_11=pd.read_csv("final.csv")
file_11
# Out:
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]

# %%
#mango_pickle
file_12=pd.read_pickle("mango_pickle")
file_12
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
#mydata.h5
file_13=pd.read_csv("mydata.h5")
file_13
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[31], line 2
#       1 #mydata.h5
# ----> 2 file_6=pd.read_csv("mydata.h5")
#       3 file_6
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
#out.csv
file_14=pd.read_csv("out.csv")
file_14
# Out:
#    Unnamed: 0 something  a   b     c   d message
# 0           0       one  1   2   3.0   4     NaN
# 1           1       two  5   6   NaN   8   world
# 2           2     three  9  10  11.0  12     foo

# %%
#out2.csv
file_15=pd.read_csv("out2.csv")
file_15
# Out:
#      Unnamed: 0  Pclass
# 0             0       3
# 1             1       1
# 2             2       3
# 3             3       1
# 4             4       3
# ..          ...     ...
# 886         886       2
# 887         887       1
# 888         888       3
# 889         889       1
# 890         890       3
#
# [891 rows x 2 columns]

# %%
#out3.csv

# %%
file_16=pd.read_csv("out3.csv")
file_16
# Out:
#     @Pclass
# 0       0@3
# 1       1@1
# 2       2@3
# 3       3@1
# 4       4@3
# ..      ...
# 886   886@2
# 887   887@1
# 888   888@3
# 889   889@1
# 890   890@3
#
# [891 rows x 1 columns]

# %%
#out5.csv

# %%
file_15=pd.read_csv("out2.csv")
file_15
# Out:
#      Unnamed: 0  Pclass
# 0             0       3
# 1             1       1
# 2             2       3
# 3             3       1
# 4             4       3
# ..          ...     ...
# 886         886       2
# 887         887       1
# 888         888       3
# 889         889       1
# 890         890       3
#
# [891 rows x 2 columns]

# %%
#out6.csv
file_16=pd.read_csv("out6.csv")
file_16
# Out:
#      one  1   2   3.0   4 Unnamed: 5
# 0    two  5   6   NaN   8      world
# 1  three  9  10  11.0  12        foo

# %%
#out7.csv

# %%
file_17=pd.read_csv("out7.csv")
file_17
# Out:
#     @Pclass
# 0       0@3
# 1       1@1
# 2       2@3
# 3       3@1
# 4       4@3
# ..      ...
# 886   886@2
# 887   887@1
# 888   888@3
# 889   889@1
# 890   890@3
#
# [891 rows x 1 columns]

# %%
#output.csv

# %%
file_18=pd.read_csv("output.csv")
file_18
# Out:
#      Unnamed: 0                                               Name  Survived
# 0             0                            Braund, Mr. Owen Harris         0
# 1             1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2             2                             Heikkinen, Miss. Laina         1
# 3             3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4             4                           Allen, Mr. William Henry         0
# ..          ...                                                ...       ...
# 886         886                              Montvila, Rev. Juozas         0
# 887         887                       Graham, Miss. Margaret Edith         1
# 888         888           Johnston, Miss. Catherine Helen "Carrie"         0
# 889         889                              Behr, Mr. Karl Howell         1
# 890         890                                Dooley, Mr. Patrick         0
#
# [891 rows x 3 columns]

# %%
#stock_px.csv

# %%
file_19=pd.read_csv("stock_px.csv")
file_19
# Out:
#                Unnamed: 0     AA    AAPL     GE     IBM    JNJ   MSFT    PEP  \
# 0     1990-02-01 00:00:00   4.98    7.86   2.87   16.79   4.27   0.51   6.04
# 1     1990-02-02 00:00:00   5.04    8.00   2.87   16.89   4.37   0.51   6.09
# 2     1990-02-05 00:00:00   5.07    8.18   2.87   17.32   4.34   0.51   6.05
# 3     1990-02-06 00:00:00   5.01    8.12   2.88   17.56   4.32   0.51   6.15
# 4     1990-02-07 00:00:00   5.04    7.77   2.91   17.93   4.38   0.51   6.17
# ...                   ...    ...     ...    ...     ...    ...    ...    ...
# 5467  2011-10-10 00:00:00  10.09  388.81  16.14  186.62  64.43  26.94  61.87
# 5468  2011-10-11 00:00:00  10.30  400.29  16.14  185.00  63.96  27.00  60.95
# 5469  2011-10-12 00:00:00  10.05  402.19  16.40  186.12  64.33  26.96  62.70
# 5470  2011-10-13 00:00:00  10.10  408.43  16.22  186.82  64.23  27.18  62.36
# 5471  2011-10-14 00:00:00  10.26  422.00  16.60  190.53  64.72  27.27  62.24
#
#           SPX    XOM
# 0      328.79   6.12
# ...

# %%
#survey_results_public.csv

# %%
file_20=pd.read_csv("survey_results_public.csv")
file_20
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
#survey_results_schema.csv

# %%
file_21=pd.read_csv("survey_results_schema.csv")
file_21
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
#survived.csv

# %%
file_22=pd.read_csv("survived.csv")
file_22
# Out:
#      Unnamed: 0                                               Name  Survived
# 0             0                            Braund, Mr. Owen Harris         0
# 1             1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2             2                             Heikkinen, Miss. Laina         1
# 3             3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4             4                           Allen, Mr. William Henry         0
# ..          ...                                                ...       ...
# 886         886                              Montvila, Rev. Juozas         0
# 887         887                       Graham, Miss. Margaret Edith         1
# 888         888           Johnston, Miss. Catherine Helen "Carrie"         0
# 889         889                              Behr, Mr. Karl Howell         1
# 890         890                                Dooley, Mr. Patrick         0
#
# [891 rows x 3 columns]

# %%
#tasty_pickle

# %%
file_23=pd.read_pickle("tasty_pickle")
file_23
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
#test.tsv
file_24=pd.read_table("test.tsv")
file_24
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
#test_file.csv

# %%
file_25=pd.read_table("test_file.csv")
file_25
# Out:
#        a,"b","c"
# 0      1,"2","3"
# 1  1,"2","3","4"

# %%
#titan.csv

# %%
file_26=pd.read_csv("titan.csv")
file_26
# Out:
#      Unnamed: 0                                               Name  Survived
# 0             0                            Braund, Mr. Owen Harris         0
# 1             1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2             2                             Heikkinen, Miss. Laina         1
# 3             3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4             4                           Allen, Mr. William Henry         0
# ..          ...                                                ...       ...
# 886         886                              Montvila, Rev. Juozas         0
# 887         887                       Graham, Miss. Margaret Edith         1
# 888         888           Johnston, Miss. Catherine Helen "Carrie"         0
# 889         889                              Behr, Mr. Karl Howell         1
# 890         890                                Dooley, Mr. Patrick         0
#
# [891 rows x 3 columns]

# %%
#tseries.csv

# %%
file_27=pd.read_csv("tseries.csv")
file_27
# Out:
#    Unnamed: 0  0
# 0  2021-01-01  0
# 1  2021-01-02  1
# 2  2021-01-03  2
# 3  2021-01-04  3
# 4  2021-01-05  4
# 5  2021-01-06  5
# 6  2021-01-07  6

# %%
# writeable_file.csv

# %%
file_28=pd.read_csv("writeable_file.csv")
file_28
# Out:
#       test     test   test.1   test.2  test.3
# 0   Magnus   Magnus   Magnus   Magnus     NaN
# 1  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %% [markdown]
# ## 2-Create a data frame which contains name and age of workshop participants(random age)-both dictionary and list

# %%
workshop={"Arjun":"31","Midhun":"26","Vivek":"34"}
workshop
# Out:
# {'Arjun': '31', 'Midhun': '26', 'Vivek': '34'}

# %%
pd.Series(workshop)
# Out:
# Arjun     31
# Midhun    26
# Vivek     34
# dtype: object

# %%
pd.DataFrame(workshop,index=["age"])
# Out:
#     Arjun Midhun Vivek
# age    31     26    34

# %%
import random as rnd

# %%
print(rnd.randint(1,10))
# Out:
# 1

# %%
workshop={"NAME":["Abhijith","Arjun","Farook","Nihal"],"AGE":["31","32","28","34"]}
pd.DataFrame(workshop)
# Out:
#        NAME AGE
# 0  Abhijith  31
# 1     Arjun  32
# 2    Farook  28
# 3     Nihal  34

# %% [markdown]
# ## 3-Read 5 different data sets and perform basics tasks

# %% [markdown]
# ##### 1- fdic_failed_bank_list.html

# %%
datas=pd.read_html("fdic_failed_bank_list.html")
datas
# Out:
# [                             Bank Name             City  ST   CERT  \
#  0                          Allied Bank         Mulberry  AR     91
#  1         The Woodbury Banking Company         Woodbury  GA  11297
#  2               First CornerStone Bank  King of Prussia  PA  35312
#  3                   Trust Company Bank          Memphis  TN   9956
#  4           North Milwaukee State Bank        Milwaukee  WI  20364
#  ..                                 ...              ...  ..    ...
#  542                 Superior Bank, FSB         Hinsdale  IL  32646
#  543                Malta National Bank            Malta  OH   6629
#  544    First Alliance Bank & Trust Co.       Manchester  NH  34264
#  545  National State Bank of Metropolis       Metropolis  IL   3815
#  546                   Bank of Honolulu         Honolulu  HI  21029
#
#                     Acquiring Institution        Closing Date  \
#  0                           Today's Bank  September 23, 2016
# ...

# %%
sets=datas[0]
sets
# Out:
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# ...

# %%
sets.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
sets.tail()
# Out:
#                              Bank Name        City  ST   CERT  \
# 542                 Superior Bank, FSB    Hinsdale  IL  32646
# 543                Malta National Bank       Malta  OH   6629
# 544    First Alliance Bank & Trust Co.  Manchester  NH  34264
# 545  National State Bank of Metropolis  Metropolis  IL   3815
# 546                   Bank of Honolulu    Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date       Updated Date
# 542                Superior Federal, FSB      July 27, 2001    August 19, 2014
# 543                    North Valley Bank        May 3, 2001  November 18, 2002
# 544  Southern New Hampshire Bank & Trust   February 2, 2001  February 18, 2003
# 545              Banterra Bank of Marion  December 14, 2000     March 17, 2005
# 546                   Bank of the Orient   October 13, 2000     March 17, 2005

# %%
sets.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %%
sets.shape
# Out:
# (547, 7)

# %%
sets.size
# Out:
# 3829

# %%
sets["Bank Name"].unique()
# Out:
# array(['Allied Bank', 'The Woodbury Banking Company',
#        'First CornerStone Bank', 'Trust Company Bank',
#        'North Milwaukee State Bank', 'Hometown National Bank',
#        'The Bank of Georgia', 'Premier Bank', 'Edgebrook Bank',
#        'Doral Bank  En Espanol', 'Capitol City Bank & Trust Company',
#        'Highland Community Bank', 'First National Bank of Crestview',
#        'Northern Star Bank', 'Frontier Bank, FSB D/B/A El Paseo Bank',
#        'The National Republic Bank of Chicago', 'NBRS Financial',
#        'GreenChoice Bank, fsb', 'Eastside Commercial Bank',
#        'The Freedom State Bank', 'Valley Bank',
#        'Slavie Federal Savings Bank', 'Columbia Savings Bank',
#        'AztecAmerica Bank En Espanol', 'Allendale County Bank',
#        'Vantage Point Bank', 'Millennium Bank, National Association',
#        'Syringa Bank', 'The Bank of Union', 'DuPage National Bank',
#        'Texas Community Bank, National Association',
# ...

# %%
sets.dtypes
# Out:
# Bank Name                object
# City                     object
# ST                       object
# CERT                      int64
# Acquiring Institution    object
# Closing Date             object
# Updated Date             object
# dtype: object

# %%
sets.select_dtypes("object")
# Out:
#                              Bank Name             City  ST  \
# 0                          Allied Bank         Mulberry  AR
# 1         The Woodbury Banking Company         Woodbury  GA
# 2               First CornerStone Bank  King of Prussia  PA
# 3                   Trust Company Bank          Memphis  TN
# 4           North Milwaukee State Bank        Milwaukee  WI
# ..                                 ...              ...  ..
# 542                 Superior Bank, FSB         Hinsdale  IL
# 543                Malta National Bank            Malta  OH
# 544    First Alliance Bank & Trust Co.       Manchester  NH
# 545  National State Bank of Metropolis       Metropolis  IL
# 546                   Bank of Honolulu         Honolulu  HI
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# 1                            United Bank     August 19, 2016
# ...

# %% [markdown]
# ##### 2-survey_results_schema.csv

# %%
data_2=pd.read_csv("survey_results_schema.csv")
data_2
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
data_2.head()
# Out:
#         Column                                       QuestionText
# 0   Respondent  Randomized respondent ID number (not in order ...
# 1   MainBranch  Which of the following options best describes ...
# 2     Hobbyist                            Do you code as a hobby?
# 3  OpenSourcer        How often do you contribute to open source?
# 4   OpenSource  How do you feel about the quality of open sour...

# %%
data_2.tail()
# Out:
#           Column                                       QuestionText
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...

# %%
data_2.columns
# Out:
# Index(['Column', 'QuestionText'], dtype='object')

# %%
data_2.shape
# Out:
# (85, 2)

# %%
data_2.size
# Out:
# 170

# %%
data_2["Column"].unique()
# Out:
# array(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer',
#        'OpenSource', 'Employment', 'Country', 'Student', 'EdLevel',
#        'UndergradMajor', 'EduOther', 'OrgSize', 'DevType', 'YearsCode',
#        'Age1stCode', 'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot',
#        'MgrMoney', 'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt',
#        'FizzBuzz', 'JobFactors', 'ResumeUpdate', 'CurrencySymbol',
#        'CurrencyDesc', 'CompTotal', 'CompFreq', 'ConvertedComp',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote',
#        'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data_2.dtypes
# Out:
# Column          object
# QuestionText    object
# dtype: object

# %%
data_2.select_dtypes("O")
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %% [markdown]
# ##### 3-demo1.xlsx

# %%
data_3=pd.read_excel("demo1.xlsx")
data_3
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
data_3.head(1)
# Out:
#    Unnamed: 0  a  b  c  d message
# 0           0  1  2  3  4   hello

# %%
data_3.tail(2)
# Out:
#    Unnamed: 0  a   b   c   d message
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
data_3.columns
# Out:
# Index(['Unnamed: 0', 'a', 'b', 'c', 'd', 'message'], dtype='object')

# %%
data_3.shape
# Out:
# (3, 6)

# %%
data_3.size
# Out:
# 18

# %%
data_3["message"].unique()
# Out:
# array(['hello', 'world', 'foo'], dtype=object)

# %%
data_3.dtypes
# Out:
# Unnamed: 0     int64
# a              int64
# b              int64
# c              int64
# d              int64
# message       object
# dtype: object

# %%
data_3.select_dtypes("object")
# Out:
#   message
# 0   hello
# 1   world
# 2     foo

# %% [markdown]
# ##### 4-test.tsv

# %%
data_4=pd.read_table("test.tsv")
data_4
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
data_4.head(1)
# Out:
#                  test    test  test.1  test.2  test.3
# Magnus Magnus  Magnus  Magnus  Magnus  Magnus     NaN

# %%
data_4.tail(1)
# Out:
#                     test     test   test.1   test.2  test.3
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
data_4.columns
# Out:
# Index(['test', ' test', 'test.1', 'test.2', 'test.3'], dtype='object')

# %%
data_4.shape
# Out:
# (2, 5)

# %%
data_4.size
# Out:
# 10

# %%
data_4["test.2"].unique()
# Out:
# array(['Magnus', 'Carlsen'], dtype=object)

# %%
data_4.dtypes
# Out:
# test       object
#  test      object
# test.1     object
# test.2     object
# test.3    float64
# dtype: object

# %%
data_4.select_dtypes("float64")
# Out:
#                  test.3
# Magnus  Magnus      NaN
# Carlsen Carlsen     NaN

# %% [markdown]
# ##### 5-"https://www.basketball-reference.com/players/c/collijo01.html"

# %%
url="https://www.basketball-reference.com/players/c/collijo01.html"
data=pd.read_html(url)
data
# Out:
# [    Season   Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...    FT%  ORB  \
#  0  2017-18  20.0  ATL  NBA   PF   74   26  24.1  4.2   7.4  ...  0.715  2.4
#  1  2018-19  21.0  ATL  NBA   PF   61   59  30.0  7.6  13.6  ...  0.763  3.6
#  2  2019-20  22.0  ATL  NBA   PF   41   41  33.2  8.6  14.8  ...  0.800  2.8
#  3  2020-21  23.0  ATL  NBA   PF   63   63  29.3  6.8  12.2  ...  0.833  1.9
#  4  2021-22  24.0  ATL  NBA   PF   54   53  30.8  6.3  11.9  ...  0.793  1.7
#  5  2022-23  25.0  ATL  NBA   PF   71   71  30.0  5.1  10.0  ...  0.803  1.1
#  6   Career   NaN  NaN  NBA  NaN  364  313  29.2  6.2  11.3  ...  0.783  2.2
#
#     DRB   TRB  AST  STL  BLK  TOV   PF   PTS
#  0  4.9   7.3  1.3  0.6  1.1  1.4  2.9  10.5
#  1  6.2   9.8  2.0  0.4  0.6  2.0  3.3  19.5
#  2  7.3  10.1  1.5  0.8  1.6  1.8  3.4  21.6
#  3  5.5   7.4  1.2  0.5  1.0  1.3  3.1  17.6
#  4  6.1   7.8  1.8  0.6  1.0  1.1  3.0  16.2
#  5  5.4   6.5  1.2  0.6  1.0  1.1  3.1  13.1
# ...

# %%
data_5=data[0]
data_5
# Out:
#     Season   Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...    FT%  ORB  \
# 0  2017-18  20.0  ATL  NBA   PF   74   26  24.1  4.2   7.4  ...  0.715  2.4
# 1  2018-19  21.0  ATL  NBA   PF   61   59  30.0  7.6  13.6  ...  0.763  3.6
# 2  2019-20  22.0  ATL  NBA   PF   41   41  33.2  8.6  14.8  ...  0.800  2.8
# 3  2020-21  23.0  ATL  NBA   PF   63   63  29.3  6.8  12.2  ...  0.833  1.9
# 4  2021-22  24.0  ATL  NBA   PF   54   53  30.8  6.3  11.9  ...  0.793  1.7
# 5  2022-23  25.0  ATL  NBA   PF   71   71  30.0  5.1  10.0  ...  0.803  1.1
# 6   Career   NaN  NaN  NBA  NaN  364  313  29.2  6.2  11.3  ...  0.783  2.2
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  4.9   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1  6.2   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  7.3  10.1  1.5  0.8  1.6  1.8  3.4  21.6
# 3  5.5   7.4  1.2  0.5  1.0  1.3  3.1  17.6
# 4  6.1   7.8  1.8  0.6  1.0  1.1  3.0  16.2
# 5  5.4   6.5  1.2  0.6  1.0  1.1  3.1  13.1
# 6  5.8   8.0  1.5  0.6  1.0  1.4  3.1  15.8
#
# ...

# %%
data_5.head()
# Out:
#     Season   Age   Tm   Lg Pos   G  GS    MP   FG   FGA  ...    FT%  ORB  DRB  \
# 0  2017-18  20.0  ATL  NBA  PF  74  26  24.1  4.2   7.4  ...  0.715  2.4  4.9
# 1  2018-19  21.0  ATL  NBA  PF  61  59  30.0  7.6  13.6  ...  0.763  3.6  6.2
# 2  2019-20  22.0  ATL  NBA  PF  41  41  33.2  8.6  14.8  ...  0.800  2.8  7.3
# 3  2020-21  23.0  ATL  NBA  PF  63  63  29.3  6.8  12.2  ...  0.833  1.9  5.5
# 4  2021-22  24.0  ATL  NBA  PF  54  53  30.8  6.3  11.9  ...  0.793  1.7  6.1
#
#     TRB  AST  STL  BLK  TOV   PF   PTS
# 0   7.3  1.3  0.6  1.1  1.4  2.9  10.5
# 1   9.8  2.0  0.4  0.6  2.0  3.3  19.5
# 2  10.1  1.5  0.8  1.6  1.8  3.4  21.6
# 3   7.4  1.2  0.5  1.0  1.3  3.1  17.6
# 4   7.8  1.8  0.6  1.0  1.1  3.0  16.2
#
# [5 rows x 30 columns]

# %%
data_5.tail()
# Out:
#     Season   Age   Tm   Lg  Pos    G   GS    MP   FG   FGA  ...    FT%  ORB  \
# 2  2019-20  22.0  ATL  NBA   PF   41   41  33.2  8.6  14.8  ...  0.800  2.8
# 3  2020-21  23.0  ATL  NBA   PF   63   63  29.3  6.8  12.2  ...  0.833  1.9
# 4  2021-22  24.0  ATL  NBA   PF   54   53  30.8  6.3  11.9  ...  0.793  1.7
# 5  2022-23  25.0  ATL  NBA   PF   71   71  30.0  5.1  10.0  ...  0.803  1.1
# 6   Career   NaN  NaN  NBA  NaN  364  313  29.2  6.2  11.3  ...  0.783  2.2
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 2  7.3  10.1  1.5  0.8  1.6  1.8  3.4  21.6
# 3  5.5   7.4  1.2  0.5  1.0  1.3  3.1  17.6
# 4  6.1   7.8  1.8  0.6  1.0  1.1  3.0  16.2
# 5  5.4   6.5  1.2  0.6  1.0  1.1  3.1  13.1
# 6  5.8   8.0  1.5  0.6  1.0  1.4  3.1  15.8
#
# [5 rows x 30 columns]

# %%
data_5.columns
# Out:
# Index(['Season', 'Age', 'Tm', 'Lg', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
data_5["Age"].unique()
# Out:
# array([20., 21., 22., 23., 24., 25., nan])

# %%
data_5.dtypes
# Out:
# Season     object
# Age       float64
# Tm         object
# Lg         object
# Pos        object
# G           int64
# GS          int64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# dtype: object

# %%
data_5.select_dtypes("int64")
# Out:
#      G   GS
# 0   74   26
# 1   61   59
# 2   41   41
# 3   63   63
# 4   54   53
# 5   71   71
# 6  364  313

# %% [markdown]
# ## 4-Write a csv from tsv and excel

# %%
#tsv

# %%
file=pd.read_table("test.tsv")
file
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
file=pd.read_csv("test.tsv",sep="\t")
file
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
csv_file=file.to_csv("writeable_file.csv")

# %%
csv_file=file.to_csv("writeable_file.csv",index=False)

# %%
#excel
data=pd.read_excel("demo1.xlsx")
data
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
csv_data=data.to_csv("new_demo1.csv")

# %%
csv_data=data.to_csv("new_demo1.csv",index=False)

# %% [markdown]
# ## 5-read one data set from each resources of dataset we discussed

# %%
#csv
file_1=pd.read_csv("demo1.csv")
file_1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
#excel
file_2=pd.read_excel("demo1.xlsx")
file_2
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
#htm
file_3=pd.read_html("fdic_failed_bank_list.html")
file_3
# Out:
# [                             Bank Name             City  ST   CERT  \
#  0                          Allied Bank         Mulberry  AR     91
#  1         The Woodbury Banking Company         Woodbury  GA  11297
#  2               First CornerStone Bank  King of Prussia  PA  35312
#  3                   Trust Company Bank          Memphis  TN   9956
#  4           North Milwaukee State Bank        Milwaukee  WI  20364
#  ..                                 ...              ...  ..    ...
#  542                 Superior Bank, FSB         Hinsdale  IL  32646
#  543                Malta National Bank            Malta  OH   6629
#  544    First Alliance Bank & Trust Co.       Manchester  NH  34264
#  545  National State Bank of Metropolis       Metropolis  IL   3815
#  546                   Bank of Honolulu         Honolulu  HI  21029
#
#                     Acquiring Institution        Closing Date  \
#  0                           Today's Bank  September 23, 2016
# ...

# %%
#tsv
file_5=pd.read_table("test.tsv")
file_5
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
#pickle
file_6=pd.read_pickle("mango_pickle")
file_6
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
file_23=pd.read_pickle("tasty_pickle")
file_23
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file
